# %%
import pandas as pd
import matplotlib.pyplot as plt

file = open('test.txt','r')
print(file.readline())
file.close()

df = pd.read_csv('test.txt', sep = ',', header = 1)
# Out:
# P:35.00,I:0.20,D:-0.40

# %%
df
# Out:
#      TIME  gyroAngle
# 0     678      -1.57
# 1     702      -1.49
# 2     726      -1.57
# 3     749      -0.75
# 4     773      -0.25
# ..    ...        ...
# 175  4655      19.04
# 176  4677      18.52
# 177  4699      18.25
# 178  4721      17.87
# 179  4744      17.73
#
# [180 rows x 2 columns]

# %%
plt.plot(df['TIME'], df['gyroAngle'])

# %% [raw]
# help(plt.plot)
